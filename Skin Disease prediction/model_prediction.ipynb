# %%
import tensorflow as tf
import numpy as np
from PIL import Image
import cv2

# %%
## Load the saved model
model=tf.keras.models.load_model('my_model.h6')
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# ...

# %%
image= cv2.imread(r"C:\Users\rakes\Skin_Cancer_detection\Skin Disease prediction\images\pigmented benign keratosis\ISIC_0024654.jpg")
image=cv2.resize(image,(180,180))

# %%
import matplotlib.pyplot as plt
# Convert the image to a NumPy array
image_array = tf.keras.preprocessing.image.img_to_array(image)

# Normalize the pixel values
#image_array = image_array / 100.0
# Rescale the pixel values to [0, 1]
rescaling_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1.)
image_array = rescaling_layer(image_array)

# Add a batch dimension
image_array = np.expand_dims(image_array, axis=0)

# Make the prediction
prediction = model.predict(image_array)

# Convert the prediction to a class label
class_names = ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']
predicted_class_index = np.argmax(prediction)
predicted_class_name = class_names[predicted_class_index]
plt.imshow(image)
plt.show()
print('The predicted class is:', predicted_class_name)
# Out:
# 1/1 [==============================] - 0s 186ms/step
# The predicted class is: pigmented benign keratosis

# %%
import pickle

# %%
with open ('skin_model.pkl','wb') as f:
    pickle.dump(my_model.h6,f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13992\3825863961.py in <module>
#       1 with open ('skin_model.pkl','wb') as f:
# ----> 2     pickle.dump(my_model.h6,f)
#
# NameError: name 'my_model' is not defined
